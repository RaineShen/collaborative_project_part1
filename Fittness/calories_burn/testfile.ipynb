# %%
from monitoring import Monitoring
from  records import Records


name = input("Please Enter name: ")
gender = input("Please Enter your gender (female or male): ")
age= int(input("Please Enter your age (integer): "))
height= int(input("Please Enter your height in cm: "  ))
weight= int(input("Please Enter your weight in kg: "))



P1=Records(name,gender,age,height,weight)
P1.display()
P1.BMI()
P1.BMR()
P1.totalcal()



print("You could calculate your burned calories for today from Records.totalcal")
calory=float(input("Please Enter your calory in kcal: "))


M1=Monitoring(name,gender,age,height,weight,calory)
M1.new_weight(55)
M1.new_calory(1893)
M1.new_weight(56.4)
M1.new_calory(1993)
M1.new_weight(57.4)
M1.new_calory(1893)
M1.new_weight(58.4)
M1.new_calory(1893)
M1.new_weight(58.4)
M1.weight_calory_plot()
M1.weight_change_plot()
M1.calory_change_plot()
# Out:
# Please Enter name:  wang
# Please Enter your gender (female or male):  female
# Please Enter your age (integer):  45
# Please Enter your height in cm:  178
# Please Enter your weight in kg:  68
# Name: wang Age: 45 Gender:female Height: 178cm Wegiht: 68kg
# Hello,wang your BMI is 21.46 which is in normal range
# Hello,wang your BMR is around 1416.7 Kcal/day
# Did you do any exercises today (Yes/No):  No
# Hello,the total burned calories for today is 1417 Kcal
# You could calculate your burned calories for today from Records.totalcal
# Please Enter your calory in kcal:  1417
